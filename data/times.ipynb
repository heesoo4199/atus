# %%
import pandas as pd
merge = pd.read_csv("merge.csv")
merge
# Out:
#          Unnamed: 0              id       category  income  start   end
# 0                 0  20030100013280         sports       1    240   300
# 1                 1  20030100013280          sleep       1    330   930
# 2                 2  20030100013280  entertainment       1    930  1080
# 3                 3  20030100013280         eating       1   1080  1085
# 4                 4  20030100013280  entertainment       1   1085  1260
# 5                 5  20030100013280          sleep       1   1260    90
# 6                 6  20030100013280         sports       1    100   270
# 7                 7  20030100013352          sleep       1    240   540
# 8                 8  20030100013352         eating       1    600   630
# 9                 9  20030100013352       shopping       1    635   695
# 10               10  20030100013352      household       1    700   715
# 11               11  20030100013352  entertainment       1    715   835
# ...

# %%
df = pd.DataFrame(columns=('time', 'activity', 'percent_0', 'percent_1', 'percent_2', 'percent_3'))
time = []
for x in range (0, 60*24, 5):
    for i in range(0,10):
        time.append(x)
df['time'] = time
df
# Out:
#       time activity percent_0 percent_1 percent_2 percent_3
# 0        0      NaN       NaN       NaN       NaN       NaN
# 1        0      NaN       NaN       NaN       NaN       NaN
# 2        0      NaN       NaN       NaN       NaN       NaN
# 3        0      NaN       NaN       NaN       NaN       NaN
# 4        0      NaN       NaN       NaN       NaN       NaN
# 5        0      NaN       NaN       NaN       NaN       NaN
# 6        0      NaN       NaN       NaN       NaN       NaN
# 7        0      NaN       NaN       NaN       NaN       NaN
# 8        0      NaN       NaN       NaN       NaN       NaN
# 9        0      NaN       NaN       NaN       NaN       NaN
# 10       5      NaN       NaN       NaN       NaN       NaN
# 11       5      NaN       NaN       NaN       NaN       NaN
# 12       5      NaN       NaN       NaN       NaN       NaN
# 13       5      NaN       NaN       NaN       NaN       NaN
# 14       5      NaN       NaN       NaN       NaN       NaN
# ...

# %%
total_acts = []
acts = ['sleep', 'socializing', 'eating', 'household', 'shopping', 'family', 'work', 'education', 'sports', 'entertainment']
for x in range (0, 60*24, 5):
    total_acts.extend(acts)
df['activity'] = total_acts
df
# Out:
#       time       activity percent_0 percent_1 percent_2 percent_3
# 0        0          sleep       NaN       NaN       NaN       NaN
# 1        0    socializing       NaN       NaN       NaN       NaN
# 2        0         eating       NaN       NaN       NaN       NaN
# 3        0      household       NaN       NaN       NaN       NaN
# 4        0       shopping       NaN       NaN       NaN       NaN
# 5        0         family       NaN       NaN       NaN       NaN
# 6        0           work       NaN       NaN       NaN       NaN
# 7        0      education       NaN       NaN       NaN       NaN
# 8        0         sports       NaN       NaN       NaN       NaN
# 9        0  entertainment       NaN       NaN       NaN       NaN
# 10       5          sleep       NaN       NaN       NaN       NaN
# 11       5    socializing       NaN       NaN       NaN       NaN
# 12       5         eating       NaN       NaN       NaN       NaN
# ...

# %%
def f(row):
    row['percent_0'] = 0
    row['percent_1'] = 0
    row['percent_2'] = 0
    row['percent_3'] = 0
    return row

df = df.apply(f, axis=1)

# %%
incomes = [0,0,0,0]
#for num in merge['income']:
#    incomes[num] += 1
for i in range (0,4):
    incomes[i] = merge[merge['income'] == i]['id'].nunique()
incomes
# Out:
# [81665, 50838, 14505, 10134]

# %%
def num(col, act, time):
    new = merge[(merge['category'] == int(act)) & (merge['income']) == int(col)]
    return 1
    '''total = 0
    time = int(time)
    for index, row in new.iterrows():
        start = int(row['start'])
        end = int(row['end'])
        duration = end - start
        if (end < start):
            duration = (1440 - start) + end
        if (start + duration) % 1440 >= time:
            total += 1'''

def f(row):
    row['percent_0'] = num('percent_0', row['activity'], row['time']) / incomes[0]
    row['percent_1'] = num('percent_1', row['activity'], row['time']) / incomes[1]
    row['percent_2'] = num('percent_2', row['activity'], row['time']) / incomes[2]
    row['percent_3'] = num('percent_3', row['activity'], row['time']) / incomes[3]
    return row

df = df.apply(f, axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c53446848eb0> in <module>
#      20     return row
#      21
# ---> 22 df = df.apply(f, axis=1)
#      23 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
# ...

# %%
col = 0
act = 'sleep'
time = 0

new = merge[(merge['category'] == act) & (merge['income']) == col]
total = 0
for index, row in new.iterrows():
    start = int(row['start'])
    end = int(row['end'])
    duration = end - start
    if (end < start):
        duration = (1440 - start) + end
    if (start + duration) % 1440 > time:
        
        if (start + duration) % 1440 < start:
            if (False):
                total += 1
        else:
            if (start <= time):
                total += 1
        
print(total)
# Out:
# 7715
